# %% [markdown]
# ### Data Sources

# %%
from onedrive_loader import files, load
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from onedrive_loader import files, load
#
# ModuleNotFoundError: No module named 'onedrive_loader'

# %% [markdown]
# ### Step 1: Import Libraries

# %%
files()
# Out:
# ['financial_transactions_dataset_analytics_kaggle',
#  'nhs-waiting-list-analytics_data',
#  'portfolio-01-nhs-financial-analytics',
#  'Portfolio-22-Financial-Performance-Analytics-Model',
#  'region_electric_hourly_time_series',
#  'SalesForecast',
#  'sundry_data_sources']

# %% [markdown]
# ____

# %%
import fda_toolkit as ftk
import pandas as pd
import numpy as np

# %%
# Set multiple display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ___

# %%
ftk.__version__
# Out:
# '0.2.8'

# %%
display(ftk.info())
# Out:
# <style type="text/css">
# ...

# %%
from fda_toolkit.core import columns, duplicates, missing, outliers, text, types

# %%
df = load("sundry_data_sources", "uk_smoking_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = load("sundry_data_sources", "uk_smoking_data.csv")
#       2 df
#
# NameError: name 'load' is not defined

# %%
# Filter by category
ftk.info(category='Core')
# Out:
# <style type="text/css">
# </style>
# <table id="T_fda-toolkit-info">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda-toolkit-info_level0_col0" class="col_heading level0 col0" >function</th>
#       <th id="T_fda-toolkit-info_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_fda-toolkit-info_level0_col2" class="col_heading level0 col2" >module</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Filter by category
ftk.info(category='Finance')
# Out:
# <style type="text/css">
# ...

# %%
# Filter by category
ftk.info(category='Validation')
# Out:
# <style type="text/css">
# #T_fda-toolkit-info_row0_col0, #T_fda-toolkit-info_row0_col1, #T_fda-toolkit-info_row0_col2, #T_fda-toolkit-info_row1_col0, #T_fda-toolkit-info_row1_col1, #T_fda-toolkit-info_row1_col2, #T_fda-toolkit-info_row2_col0, #T_fda-toolkit-info_row2_col1, #T_fda-toolkit-info_row2_col2, #T_fda-toolkit-info_row3_col0, #T_fda-toolkit-info_row3_col1, #T_fda-toolkit-info_row3_col2, #T_fda-toolkit-info_row4_col0, #T_fda-toolkit-info_row4_col1, #T_fda-toolkit-info_row4_col2, #T_fda-toolkit-info_row5_col0, #T_fda-toolkit-info_row5_col1, #T_fda-toolkit-info_row5_col2, #T_fda-toolkit-info_row6_col0, #T_fda-toolkit-info_row6_col1, #T_fda-toolkit-info_row6_col2, #T_fda-toolkit-info_row7_col0, #T_fda-toolkit-info_row7_col1, #T_fda-toolkit-info_row7_col2, #T_fda-toolkit-info_row8_col0, #T_fda-toolkit-info_row8_col1, #T_fda-toolkit-info_row8_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_fda-toolkit-info">
#   <thead>
#     <tr>
# ...

# %%
# Filter by module
ftk.info('Feature Engineering')
# Out:
# <style type="text/css">
# #T_fda-toolkit-info_row0_col0, #T_fda-toolkit-info_row0_col1, #T_fda-toolkit-info_row0_col2, #T_fda-toolkit-info_row1_col0, #T_fda-toolkit-info_row1_col1, #T_fda-toolkit-info_row1_col2, #T_fda-toolkit-info_row2_col0, #T_fda-toolkit-info_row2_col1, #T_fda-toolkit-info_row2_col2, #T_fda-toolkit-info_row3_col0, #T_fda-toolkit-info_row3_col1, #T_fda-toolkit-info_row3_col2, #T_fda-toolkit-info_row4_col0, #T_fda-toolkit-info_row4_col1, #T_fda-toolkit-info_row4_col2, #T_fda-toolkit-info_row5_col0, #T_fda-toolkit-info_row5_col1, #T_fda-toolkit-info_row5_col2, #T_fda-toolkit-info_row6_col0, #T_fda-toolkit-info_row6_col1, #T_fda-toolkit-info_row6_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_fda-toolkit-info">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda-toolkit-info_level0_col0" class="col_heading level0 col0" >function</th>
# ...

# %%
# Filter by module
ftk.info('Reporting')
# Out:
# <style type="text/css">
# #T_fda-toolkit-info_row0_col0, #T_fda-toolkit-info_row0_col1, #T_fda-toolkit-info_row0_col2, #T_fda-toolkit-info_row1_col0, #T_fda-toolkit-info_row1_col1, #T_fda-toolkit-info_row1_col2, #T_fda-toolkit-info_row2_col0, #T_fda-toolkit-info_row2_col1, #T_fda-toolkit-info_row2_col2, #T_fda-toolkit-info_row3_col0, #T_fda-toolkit-info_row3_col1, #T_fda-toolkit-info_row3_col2, #T_fda-toolkit-info_row4_col0, #T_fda-toolkit-info_row4_col1, #T_fda-toolkit-info_row4_col2, #T_fda-toolkit-info_row5_col0, #T_fda-toolkit-info_row5_col1, #T_fda-toolkit-info_row5_col2, #T_fda-toolkit-info_row6_col0, #T_fda-toolkit-info_row6_col1, #T_fda-toolkit-info_row6_col2, #T_fda-toolkit-info_row7_col0, #T_fda-toolkit-info_row7_col1, #T_fda-toolkit-info_row7_col2, #T_fda-toolkit-info_row8_col0, #T_fda-toolkit-info_row8_col1, #T_fda-toolkit-info_row8_col2, #T_fda-toolkit-info_row9_col0, #T_fda-toolkit-info_row9_col1, #T_fda-toolkit-info_row9_col2 {
#   text-align: left;
# }
# </style>
# ...

# %%
ftk.info('Data Quality')
# Out:
# <style type="text/css">
# #T_fda-toolkit-info_row0_col0, #T_fda-toolkit-info_row0_col1, #T_fda-toolkit-info_row0_col2, #T_fda-toolkit-info_row1_col0, #T_fda-toolkit-info_row1_col1, #T_fda-toolkit-info_row1_col2, #T_fda-toolkit-info_row2_col0, #T_fda-toolkit-info_row2_col1, #T_fda-toolkit-info_row2_col2, #T_fda-toolkit-info_row3_col0, #T_fda-toolkit-info_row3_col1, #T_fda-toolkit-info_row3_col2, #T_fda-toolkit-info_row4_col0, #T_fda-toolkit-info_row4_col1, #T_fda-toolkit-info_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_fda-toolkit-info">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda-toolkit-info_level0_col0" class="col_heading level0 col0" >function</th>
#       <th id="T_fda-toolkit-info_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_fda-toolkit-info_level0_col2" class="col_heading level0 col2" >module</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
